# %%
import pandas as pd
import pathlib
import glob
import os

# %%
#concate all text
path = "/Users/pr158admin/Downloads/US_VitalStatistics/"

print(path)
all_files = glob.glob(os.path.join(path, "*.txt"))
all_files
overdose_merge = pd.concat((pd.read_csv(f ,delimiter ="\t") for f in all_files))
# Out:
# /Users/pr158admin/Downloads/US_VitalStatistics/

# %%
overdose_merge.sample(10)
# Out:
#      Notes                  County  County Code    Year  Year Code  \
# 1298   NaN  Vanderburgh County, IN      18163.0  2015.0     2015.0
# 3667   NaN   Washington County, TN      47179.0  2011.0     2011.0
# 1295   NaN       Howard County, IA      19089.0  2012.0     2012.0
# 4450   NaN       Upshur County, WV      54097.0  2013.0     2013.0
# 3467   NaN     Davidson County, TN      47037.0  2009.0     2009.0
# 821    NaN     Haralson County, GA      13143.0  2013.0     2013.0
# 723    NaN     Cherokee County, GA      13057.0  2008.0     2008.0
# 2583   NaN       Mercer County, NJ      34021.0  2014.0     2014.0
# 3596   NaN       Upshur County, TX      48459.0  2003.0     2003.0
# 841    NaN          Lee County, GA      13177.0  2013.0     2013.0
#
#                              Drug/Alcohol Induced Cause  \
# 1298  Drug poisonings (overdose) Unintentional (X40-...
# 3667  Drug poisonings (overdose) Unintentional (X40-...
# 1295          All other non-drug and non-alcohol causes
# 4450          All other non-drug and non-alcohol causes
# 3467      Alcohol poisonings (overdose) (X45, X65, Y15)
# 821           All other non-drug and non-alcohol causes
# 723   Drug poisonings (overdose) Unintentional (X40-...
# 2583          All other non-drug and non-alcohol causes
# 3596          All other non-drug and non-alcohol causes
# 841           All other non-drug and non-alcohol causes
#
#      Drug/Alcohol Induced Cause Code  Deaths
# 1298                              D1      38
# 3667                              D1    15.0
# 1295                              O9    97.0
# 4450                              O9   243.0
# 3467                              A1    10.0
# 821                               O9   300.0
# 723                               D1    16.0
# 2583                              O9  2783.0
# 3596                              O9   434.0
# 841                               O9   190.0

# %%
#distinct values of columns
overdose_merge["Drug/Alcohol Induced Cause Code"].unique()
# Out:
# array(['O9', 'D1', 'D4', 'D2', 'D9', 'A9', 'A1', nan, 'D3'], dtype=object)

# %%
#filter the drug induced deaths
drug_code = ['D1','D2','D3','D4']
overdose_df = overdose_merge[overdose_merge["Drug/Alcohol Induced Cause Code"].isin(drug_code)]

# %%
overdose_df.sample(10)
# Out:
#      Notes                   County  County Code    Year  Year Code  \
# 4257   NaN         Clark County, WA      53011.0  2012.0     2012.0
# 1723   NaN  Androscoggin County, ME      23001.0  2013.0     2013.0
# 784    NaN          Hall County, GA      13139.0  2008.0     2008.0
# 1713   NaN     Frederick County, MD      24021.0  2009.0     2009.0
# 2458   NaN      Richmond County, NY      36085.0  2003.0     2003.0
# 1058   NaN         Clark County, IN      18019.0  2006.0     2006.0
# 386    NaN        Sonoma County, CA       6097.0  2007.0     2007.0
# 1065   NaN   Rock Island County, IL      17161.0  2009.0     2009.0
# 1627   NaN    Livingston Parish, LA      22063.0  2009.0     2009.0
# 3681   NaN    Cumberland County, TN      47035.0  2014.0     2014.0
#
#                              Drug/Alcohol Induced Cause  \
# 4257  Drug poisonings (overdose) Unintentional (X40-...
# 1723  Drug poisonings (overdose) Unintentional (X40-...
# 784   Drug poisonings (overdose) Unintentional (X40-...
# 1713  Drug poisonings (overdose) Undetermined (Y10-Y14)
# 2458  Drug poisonings (overdose) Unintentional (X40-...
# 1058  Drug poisonings (overdose) Unintentional (X40-...
# 386        Drug poisonings (overdose) Suicide (X60-X64)
# 1065  Drug poisonings (overdose) Unintentional (X40-...
# 1627  Drug poisonings (overdose) Unintentional (X40-...
# 3681  Drug poisonings (overdose) Unintentional (X40-...
#
#      Drug/Alcohol Induced Cause Code Deaths
# 4257                              D1   52.0
# 1723                              D1   10.0
# 784                               D1   14.0
# 1713                              D4   20.0
# 2458                              D1   26.0
# 1058                              D1   10.0
# 386                               D2   12.0
# 1065                              D1   11.0
# 1627                              D1   26.0
# 3681                              D1   14.0

# %%
#write df to csv in the  repo

overdose_df.to_csv("overdose_df.csv", encoding="utf-8", index=False)
