# %%
import pandas as pd
import pathlib
import glob
import os

# %%
#concate all text
path = "/Users/pr158admin/Downloads/US_VitalStatistics/"

print(path)
all_files = glob.glob(os.path.join(path, "*.txt"))
all_files
overdose_merge = pd.concat((pd.read_csv(f ,delimiter ="\t") for f in all_files))
# Out:
# /Users/pr158admin/Downloads/US_VitalStatistics/

# %%
overdose_merge.sample(10)
# Out:
#      Notes               County  County Code    Year  Year Code  \
# 2313   NaN    Howell County, MO      29091.0  2015.0     2015.0
# 4518   NaN    Monroe County, WI      55081.0  2013.0     2013.0
# 1178   NaN    Marion County, IN      18097.0  2011.0     2011.0
# 1976   NaN   Hancock County, MS      28045.0  2006.0     2006.0
# 4484   NaN  Waushara County, WI      55137.0  2011.0     2011.0
# 188    NaN     Logan County, AR       5083.0  2005.0     2005.0
# 4339   NaN  Big Horn County, WY      56003.0  2009.0     2009.0
# 1264   NaN  Delaware County, IA      19055.0  2011.0     2011.0
# 2603   NaN  Dutchess County, NY      36027.0  2010.0     2010.0
# 4175   NaN   Jackson County, WI      55053.0  2006.0     2006.0
#
#                              Drug/Alcohol Induced Cause  \
# 2313          All other non-drug and non-alcohol causes
# 4518          All other non-drug and non-alcohol causes
# 1178          All other non-drug and non-alcohol causes
# ...

# %%
#distinct values of columns
overdose_merge["Drug/Alcohol Induced Cause Code"].unique()
# Out:
# array(['O9', 'D1', 'D4', 'D2', 'D9', 'A9', 'A1', nan, 'D3'], dtype=object)

# %%
#filter the drug induced deaths
drug_code = ['D1','D2','D3','D4']
overdose_df = overdose_merge[overdose_merge["Drug/Alcohol Induced Cause Code"].isin(drug_code)]

# %%
overdose_df.sample(10)
# Out:
#      Notes                      County  County Code    Year  Year Code  \
# 4262   NaN       Washington County, UT      49053.0  2015.0     2015.0
# 1138   NaN           Monroe County, IN      18105.0  2007.0     2007.0
# 3239   NaN         Lawrence County, PA      42073.0  2008.0     2008.0
# 2910   NaN           Onslow County, NC      37133.0  2014.0     2014.0
# 2908   NaN       Cumberland County, NC      37051.0  2015.0     2015.0
# 133    NaN            Pinal County, AZ       4021.0  2004.0     2004.0
# 1517   NaN        Jefferson County, KY      21111.0  2010.0     2010.0
# 1724   NaN        Kalamazoo County, MI      26077.0  2004.0     2004.0
# 2390   NaN          Douglas County, NV      32005.0  2008.0     2008.0
# 357    NaN  San Luis Obispo County, CA       6079.0  2007.0     2007.0
#
#                              Drug/Alcohol Induced Cause  \
# 4262  Drug poisonings (overdose) Unintentional (X40-...
# 1138  Drug poisonings (overdose) Unintentional (X40-...
# ...

# %%
#write df to csv in the  repo

overdose_df.to_csv("overdose_df.csv", encoding="utf-8", index=False)

# %%
#filtering the states
states= ["FL","WA","TX","ME","WV","VT","AK","DC","UT","IL","LA","MD","OK"]
#overdose_df1 = overdose_df[overdose_df["County"].isin(states)]
overdose_final=overdose_df[overdose_df["County"].str.contains('|'.join(states))]
overdose_final.sample(10)
# Out:
#      Notes                 County  County Code    Year  Year Code  \
# 90     NaN  Anchorage Borough, AK       2020.0  2008.0     2008.0
# 3992   NaN  Williamson County, TX      48491.0  2011.0     2011.0
# 3689   NaN   Guadalupe County, TX      48187.0  2009.0     2009.0
# 4424   NaN      Mercer County, WV      54055.0  2013.0     2013.0
# 3987   NaN     Wichita County, TX      48485.0  2011.0     2011.0
# 1053   NaN   St. Clair County, IL      17163.0  2008.0     2008.0
# 1669   NaN     Baltimore city, MD      24510.0  2005.0     2005.0
# 4002   NaN     Raleigh County, WV      54081.0  2004.0     2004.0
# 4300   NaN    Thurston County, WA      53067.0  2011.0     2011.0
# 1067   NaN   St. Clair County, IL      17163.0  2009.0     2009.0
#
#                              Drug/Alcohol Induced Cause  \
# 90    Drug poisonings (overdose) Undetermined (Y10-Y14)
# 3992  Drug poisonings (overdose) Unintentional (X40-...
# 3689  Drug poisonings (overdose) Unintentional (X40-...
# ...

# %%
# new=overdose_final["County"].str.split(",", n=1, expand = True).copy(deep=True)
# df[['First','Last']] = df.Name.str.split(expand=True)
#overdose_final.County.str.split(",", n=1, expand = True).
overdose_copy=overdose_final.copy()
overdose_copy[['County', 'State']]= overdose_final.County.str.split(",", n=1, expand = True)

# %%
overdose_copy['County']=overdose_copy['County'].str.lower()

# %%
overdose_copy
# Out:
#      Notes                        County  County Code    Year  Year Code  \
# 90     NaN             anchorage borough       2020.0  2009.0     2009.0
# 91     NaN             anchorage borough       2020.0  2009.0     2009.0
# 97     NaN  fairbanks north star borough       2090.0  2009.0     2009.0
# 102    NaN       kenai peninsula borough       2122.0  2009.0     2009.0
# 108    NaN     matanuska-susitna borough       2170.0  2009.0     2009.0
# ...    ...                           ...          ...     ...        ...
# 4439   NaN                 putnam county      54079.0  2013.0     2013.0
# 4441   NaN                raleigh county      54081.0  2013.0     2013.0
# 4451   NaN                  wayne county      54099.0  2013.0     2013.0
# 4456   NaN                   wood county      54107.0  2013.0     2013.0
# 4458   NaN                wyoming county      54109.0  2013.0     2013.0
#
#                              Drug/Alcohol Induced Cause  \
# ...

# %%
# overdose_final["States"]=new[1].copy(deep=True)

# %%
overdose_copy.drop(['Notes','Year Code'], axis=1)
# Out:
#                             County  County Code    Year  \
# 90               anchorage borough       2020.0  2009.0
# 91               anchorage borough       2020.0  2009.0
# 97    fairbanks north star borough       2090.0  2009.0
# 102        kenai peninsula borough       2122.0  2009.0
# 108      matanuska-susitna borough       2170.0  2009.0
# ...                            ...          ...     ...
# 4439                 putnam county      54079.0  2013.0
# 4441                raleigh county      54081.0  2013.0
# 4451                  wayne county      54099.0  2013.0
# 4456                   wood county      54107.0  2013.0
# 4458                wyoming county      54109.0  2013.0
#
#                              Drug/Alcohol Induced Cause  \
# 90    Drug poisonings (overdose) Unintentional (X40-...
# 91         Drug poisonings (overdose) Suicide (X60-X64)
# 97    Drug poisonings (overdose) Unintentional (X40-...
# 102   Drug poisonings (overdose) Unintentional (X40-...
# ...

# %%
overdose_copy["County"]=overdose_copy["County"].str.replace('county', '')

# %%
overdose_copy
# Out:
#      Notes                        County  County Code    Year  Year Code  \
# 90     NaN             anchorage borough       2020.0  2009.0     2009.0
# 91     NaN             anchorage borough       2020.0  2009.0     2009.0
# 97     NaN  fairbanks north star borough       2090.0  2009.0     2009.0
# 102    NaN       kenai peninsula borough       2122.0  2009.0     2009.0
# 108    NaN     matanuska-susitna borough       2170.0  2009.0     2009.0
# ...    ...                           ...          ...     ...        ...
# 4439   NaN                       putnam       54079.0  2013.0     2013.0
# 4441   NaN                      raleigh       54081.0  2013.0     2013.0
# 4451   NaN                        wayne       54099.0  2013.0     2013.0
# 4456   NaN                         wood       54107.0  2013.0     2013.0
# 4458   NaN                      wyoming       54109.0  2013.0     2013.0
#
#                              Drug/Alcohol Induced Cause  \
# ...

# %%
overdose_copy["County"]=overdose_copy["County"].str.replace('county', '')

# %%
overdose_copy["County"] = overdose_copy["County"] +' county'

# %%
overdose_copy
# Out:
#      Notes                                County  County Code    Year  \
# 90     NaN             anchorage borough  county       2020.0  2009.0
# 91     NaN             anchorage borough  county       2020.0  2009.0
# 97     NaN  fairbanks north star borough  county       2090.0  2009.0
# 102    NaN       kenai peninsula borough  county       2122.0  2009.0
# 108    NaN     matanuska-susitna borough  county       2170.0  2009.0
# ...    ...                                   ...          ...     ...
# 4439   NaN                       putnam   county      54079.0  2013.0
# 4441   NaN                      raleigh   county      54081.0  2013.0
# 4451   NaN                        wayne   county      54099.0  2013.0
# 4456   NaN                         wood   county      54107.0  2013.0
# 4458   NaN                      wyoming   county      54109.0  2013.0
#
#       Year Code                         Drug/Alcohol Induced Cause  \
# ...
