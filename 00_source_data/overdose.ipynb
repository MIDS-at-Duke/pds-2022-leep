# %%
import pandas as pd
import pathlib
import glob
import os

# %%
#concate all text
path = "/Users/pr158admin/Downloads/US_VitalStatistics/"

print(path)
all_files = glob.glob(os.path.join(path, "*.txt"))
all_files
overdose_merge = pd.concat((pd.read_csv(f ,delimiter ="\t") for f in all_files))
# Out:
# /Users/pr158admin/Downloads/US_VitalStatistics/

# %%
overdose_merge.sample(10)
# Out:
#      Notes                   County  County Code    Year  Year Code  \
# 2797   NaN         Adair County, OK      40001.0  2003.0     2003.0
# 1386   NaN       Jackson County, KS      20085.0  2011.0     2011.0
# 4349   NaN       Laramie County, WY      56021.0  2009.0     2009.0
# 4360   NaN         Teton County, WY      56039.0  2009.0     2009.0
# 2385   NaN  Hillsborough County, NH      33011.0  2007.0     2007.0
# 784    NaN         Floyd County, GA      13115.0  2012.0     2012.0
# 1832   NaN        Itasca County, MN      27061.0  2004.0     2004.0
# 2066   NaN      Red Lake County, MN      27125.0  2013.0     2013.0
# 2576   NaN         Salem County, NJ      34033.0  2013.0     2013.0
# 2209   NaN        Phelps County, MO      29161.0  2009.0     2009.0
#
#                      Drug/Alcohol Induced Cause  \
# 2797  All other non-drug and non-alcohol causes
# 1386  All other non-drug and non-alcohol causes
# 4349           All other alcohol-induced causes
# 4360  All other non-drug and non-alcohol causes
# 2385  All other non-drug and non-alcohol causes
# 784            All other alcohol-induced causes
# 1832  All other non-drug and non-alcohol causes
# 2066  All other non-drug and non-alcohol causes
# 2576  All other non-drug and non-alcohol causes
# 2209  All other non-drug and non-alcohol causes
#
#      Drug/Alcohol Induced Cause Code  Deaths
# 2797                              O9   227.0
# 1386                              O9   136.0
# 4349                              A9    13.0
# 4360                              O9    69.0
# 2385                              O9  2802.0
# 784                               A9    11.0
# 1832                              O9   472.0
# 2066                              O9    51.0
# 2576                              O9   680.0
# 2209                              O9   393.0

# %%
#distinct values of columns
overdose_merge["Drug/Alcohol Induced Cause Code"].unique()
# Out:
# array(['O9', 'D1', 'D4', 'D2', 'D9', 'A9', 'A1', nan, 'D3'], dtype=object)

# %%
#filter the drug induced deaths
drug_code = ['D1','D2','D3','D4']
overdose_df = overdose_merge[overdose_merge["Drug/Alcohol Induced Cause Code"].isin(drug_code)]

# %%
overdose_df.sample(10)
# Out:
#      Notes                 County  County Code    Year  Year Code  \
# 3044   NaN      Mercer County, PA      42085.0  2004.0     2004.0
# 1507   NaN      Harlan County, KY      21095.0  2010.0     2010.0
# 803    NaN       Henry County, GA      13151.0  2009.0     2009.0
# 3635   NaN  Greenville County, SC      45045.0  2015.0     2015.0
# 3576   NaN     Tarrant County, TX      48439.0  2003.0     2003.0
# 3120   NaN       Bryan County, OK      40013.0  2012.0     2012.0
# 1338   NaN       Scott County, IA      19163.0  2012.0     2012.0
# 595    NaN     Manatee County, FL      12081.0  2006.0     2006.0
# 2438   NaN     Passaic County, NJ      34031.0  2007.0     2007.0
# 322    NaN   San Diego County, CA       6073.0  2004.0     2004.0
#
#                              Drug/Alcohol Induced Cause  \
# 3044  Drug poisonings (overdose) Unintentional (X40-...
# 1507  Drug poisonings (overdose) Unintentional (X40-...
# 803   Drug poisonings (overdose) Unintentional (X40-...
# 3635  Drug poisonings (overdose) Unintentional (X40-...
# 3576       Drug poisonings (overdose) Suicide (X60-X64)
# 3120  Drug poisonings (overdose) Unintentional (X40-...
# 1338  Drug poisonings (overdose) Unintentional (X40-...
# 595        Drug poisonings (overdose) Suicide (X60-X64)
# 2438  Drug poisonings (overdose) Unintentional (X40-...
# 322   Drug poisonings (overdose) Unintentional (X40-...
#
#      Drug/Alcohol Induced Cause Code Deaths
# 3044                              D1   13.0
# 1507                              D1   13.0
# 803                               D1   17.0
# 3635                              D1    100
# 3576                              D2   17.0
# 3120                              D1   12.0
# 1338                              D1   22.0
# 595                               D2   11.0
# 2438                              D1   28.0
# 322                               D1  225.0

# %%
#write df to csv in the  repo

overdose_df.to_csv("overdose_df.csv", encoding="utf-8", index=False)

# %%
#filtering the states
states= ["FL","WA","TX","ME","WV","VT","AK","DC","UT","IL","LA","MD","OK"]
#overdose_df1 = overdose_df[overdose_df["County"].isin(states)]
overdose_final=overdose_df[overdose_df["County"].str.contains('|'.join(states))]
overdose_final.sample(10)
# Out:
#      Notes                 County  County Code    Year  Year Code  \
# 1809   NaN  Montgomery County, MD      24031.0  2014.0     2014.0
# 665    NaN  Santa Rosa County, FL      12113.0  2007.0     2007.0
# 3574   NaN      Nueces County, TX      48355.0  2004.0     2004.0
# 3868   NaN     Rutland County, VT      50021.0  2007.0     2007.0
# 4513   NaN        King County, WA      53033.0  2015.0     2015.0
# 3706   NaN   Henderson County, TX      48213.0  2008.0     2008.0
# 1040   NaN     Madison County, IL      17119.0  2010.0     2010.0
# 3243   NaN       Tulsa County, OK      40143.0  2013.0     2013.0
# 4077   NaN      Pierce County, WA      53053.0  2007.0     2007.0
# 586    NaN     Manatee County, FL      12081.0  2005.0     2005.0
#
#                              Drug/Alcohol Induced Cause  \
# 1809       Drug poisonings (overdose) Suicide (X60-X64)
# 665   Drug poisonings (overdose) Unintentional (X40-...
# 3574  Drug poisonings (overdose) Unintentional (X40-...
# 3868  Drug poisonings (overdose) Unintentional (X40-...
# 4513  Drug poisonings (overdose) Undetermined (Y10-Y14)
# 3706  Drug poisonings (overdose) Unintentional (X40-...
# 1040  Drug poisonings (overdose) Unintentional (X40-...
# 3243  Drug poisonings (overdose) Unintentional (X40-...
# 4077  Drug poisonings (overdose) Unintentional (X40-...
# 586   Drug poisonings (overdose) Unintentional (X40-...
#
#      Drug/Alcohol Induced Cause Code Deaths
# 1809                              D2   12.0
# 665                               D1   20.0
# 3574                              D1   18.0
# 3868                              D1   12.0
# 4513                              D4     10
# 3706                              D1   10.0
# 1040                              D1   57.0
# 3243                              D1  106.0
# 4077                              D1   98.0
# 586                               D1   43.0

# %%
# new=overdose_final["County"].str.split(",", n=1, expand = True).copy(deep=True)
# df[['First','Last']] = df.Name.str.split(expand=True)
#overdose_final.County.str.split(",", n=1, expand = True).
overdose_copy=overdose_final.copy()
overdose_copy[['County', 'State']]= overdose_final.County.str.split(",", n=1, expand = True)

# %%
overdose_copy['County']=overdose_copy['County'].str.lower()

# %%
overdose_copy
# Out:
#      Notes                        County  County Code    Year  Year Code  \
# 90     NaN             anchorage borough       2020.0  2009.0     2009.0
# 91     NaN             anchorage borough       2020.0  2009.0     2009.0
# 97     NaN  fairbanks north star borough       2090.0  2009.0     2009.0
# 102    NaN       kenai peninsula borough       2122.0  2009.0     2009.0
# 108    NaN     matanuska-susitna borough       2170.0  2009.0     2009.0
# ...    ...                           ...          ...     ...        ...
# 4439   NaN                 putnam county      54079.0  2013.0     2013.0
# 4441   NaN                raleigh county      54081.0  2013.0     2013.0
# 4451   NaN                  wayne county      54099.0  2013.0     2013.0
# 4456   NaN                   wood county      54107.0  2013.0     2013.0
# 4458   NaN                wyoming county      54109.0  2013.0     2013.0
#
#                              Drug/Alcohol Induced Cause  \
# 90    Drug poisonings (overdose) Unintentional (X40-...
# 91         Drug poisonings (overdose) Suicide (X60-X64)
# 97    Drug poisonings (overdose) Unintentional (X40-...
# 102   Drug poisonings (overdose) Unintentional (X40-...
# 108   Drug poisonings (overdose) Unintentional (X40-...
# ...                                                 ...
# 4439  Drug poisonings (overdose) Unintentional (X40-...
# 4441  Drug poisonings (overdose) Unintentional (X40-...
# 4451  Drug poisonings (overdose) Unintentional (X40-...
# 4456  Drug poisonings (overdose) Unintentional (X40-...
# 4458  Drug poisonings (overdose) Unintentional (X40-...
#
#      Drug/Alcohol Induced Cause Code Deaths State
# 90                                D1   46.0    AK
# 91                                D2   11.0    AK
# 97                                D1   16.0    AK
# 102                               D1   11.0    AK
# 108                               D1   15.0    AK
# ...                              ...    ...   ...
# 4439                              D1   11.0    WV
# 4441                              D1   33.0    WV
# 4451                              D1   17.0    WV
# 4456                              D1   16.0    WV
# 4458                              D1   14.0    WV
#
# [2717 rows x 9 columns]

# %%
# overdose_final["States"]=new[1].copy(deep=True)

# %%
overdose_copy.drop(['Notes','Year Code'], axis=1)
# Out:
#                             County  County Code    Year  \
# 90               anchorage borough       2020.0  2009.0
# 91               anchorage borough       2020.0  2009.0
# 97    fairbanks north star borough       2090.0  2009.0
# 102        kenai peninsula borough       2122.0  2009.0
# 108      matanuska-susitna borough       2170.0  2009.0
# ...                            ...          ...     ...
# 4439                 putnam county      54079.0  2013.0
# 4441                raleigh county      54081.0  2013.0
# 4451                  wayne county      54099.0  2013.0
# 4456                   wood county      54107.0  2013.0
# 4458                wyoming county      54109.0  2013.0
#
#                              Drug/Alcohol Induced Cause  \
# 90    Drug poisonings (overdose) Unintentional (X40-...
# 91         Drug poisonings (overdose) Suicide (X60-X64)
# 97    Drug poisonings (overdose) Unintentional (X40-...
# 102   Drug poisonings (overdose) Unintentional (X40-...
# 108   Drug poisonings (overdose) Unintentional (X40-...
# ...                                                 ...
# 4439  Drug poisonings (overdose) Unintentional (X40-...
# 4441  Drug poisonings (overdose) Unintentional (X40-...
# 4451  Drug poisonings (overdose) Unintentional (X40-...
# 4456  Drug poisonings (overdose) Unintentional (X40-...
# 4458  Drug poisonings (overdose) Unintentional (X40-...
#
#      Drug/Alcohol Induced Cause Code Deaths State
# 90                                D1   46.0    AK
# 91                                D2   11.0    AK
# 97                                D1   16.0    AK
# 102                               D1   11.0    AK
# 108                               D1   15.0    AK
# ...                              ...    ...   ...
# 4439                              D1   11.0    WV
# 4441                              D1   33.0    WV
# 4451                              D1   17.0    WV
# 4456                              D1   16.0    WV
# 4458                              D1   14.0    WV
#
# [2717 rows x 7 columns]
