# %%
import pandas as pd
import pathlib
import glob
import os

# %%
#concate all text
path = "/Users/pr158admin/Downloads/US_VitalStatistics/"

print(path)
all_files = glob.glob(os.path.join(path, "*.txt"))
all_files
overdose_merge = pd.concat((pd.read_csv(f ,delimiter ="\t") for f in all_files))
# Out:
# /Users/pr158admin/Downloads/US_VitalStatistics/

# %%
overdose_merge.sample(10)
# Out:
#      Notes                 County  County Code    Year  Year Code  \
# 1910   NaN    Franklin County, MS      28037.0  2004.0     2004.0
# 286    NaN        Lake County, CA       6033.0  2011.0     2011.0
# 1281   NaN      Taylor County, IA      19173.0  2007.0     2007.0
# 1534   NaN   Claiborne Parish, LA      22027.0  2005.0     2005.0
# 2197   NaN    Frontier County, NE      31063.0  2004.0     2004.0
# 4248   NaN        Wood County, WV      54107.0  2008.0     2008.0
# 2761   NaN  Washington County, NC      37187.0  2007.0     2007.0
# 59     NaN     Madison County, AL       1089.0  2015.0     2015.0
# 1743   NaN      Ogemaw County, MI      26129.0  2003.0     2003.0
# 2026   NaN       Smith County, MS      28129.0  2006.0     2006.0
#
#                      Drug/Alcohol Induced Cause  \
# 1910  All other non-drug and non-alcohol causes
# 286   All other non-drug and non-alcohol causes
# 1281  All other non-drug and non-alcohol causes
# 1534  All other non-drug and non-alcohol causes
# 2197  All other non-drug and non-alcohol causes
# 4248  All other non-drug and non-alcohol causes
# 2761  All other non-drug and non-alcohol causes
# 59    All other non-drug and non-alcohol causes
# 1743  All other non-drug and non-alcohol causes
# 2026  All other non-drug and non-alcohol causes
#
#      Drug/Alcohol Induced Cause Code Deaths
# 1910                              O9   94.0
# 286                               O9  769.0
# 1281                              O9   88.0
# 1534                              O9  206.0
# 2197                              O9   20.0
# 4248                              O9  994.0
# 2761                              O9  168.0
# 59                                O9   2953
# 1743                              O9  277.0
# 2026                              O9  220.0

# %%
#distinct values of columns
overdose_merge["Drug/Alcohol Induced Cause Code"].unique()
# Out:
# array(['O9', 'D1', 'D4', 'D2', 'D9', 'A9', 'A1', nan, 'D3'], dtype=object)

# %%
#filter the drug induced deaths
drug_code = ['D1','D2','D3','D4']
overdose_df = overdose_merge[overdose_merge["Drug/Alcohol Induced Cause Code"].isin(drug_code)]

# %%
overdose_df.sample(10)
# Out:
#      Notes                 County  County Code    Year  Year Code  \
# 773    NaN     Forsyth County, GA      13117.0  2009.0     2009.0
# 2422   NaN      Chaves County, NM      35005.0  2005.0     2005.0
# 292    NaN      Madera County, CA       6039.0  2008.0     2008.0
# 2974   NaN    Lawrence County, OH      39087.0  2010.0     2010.0
# 1737   NaN       Essex County, MA      25009.0  2008.0     2008.0
# 561    NaN     Collier County, FL      12021.0  2007.0     2007.0
# 1861   NaN     Oakland County, MI      26125.0  2008.0     2008.0
# 3845   NaN     Henrico County, VA      51087.0  2005.0     2005.0
# 2871   NaN  Montgomery County, OH      39113.0  2006.0     2006.0
# 2250   NaN      Washoe County, NV      32031.0  2003.0     2003.0
#
#                              Drug/Alcohol Induced Cause  \
# 773   Drug poisonings (overdose) Unintentional (X40-...
# 2422  Drug poisonings (overdose) Unintentional (X40-...
# 292   Drug poisonings (overdose) Unintentional (X40-...
# 2974  Drug poisonings (overdose) Unintentional (X40-...
# 1737       Drug poisonings (overdose) Suicide (X60-X64)
# 561   Drug poisonings (overdose) Unintentional (X40-...
# 1861       Drug poisonings (overdose) Suicide (X60-X64)
# 3845  Drug poisonings (overdose) Unintentional (X40-...
# 2871  Drug poisonings (overdose) Unintentional (X40-...
# 2250       Drug poisonings (overdose) Suicide (X60-X64)
#
#      Drug/Alcohol Induced Cause Code Deaths
# 773                               D1   13.0
# 2422                              D1   13.0
# 292                               D1   11.0
# 2974                              D1   11.0
# 1737                              D2   16.0
# 561                               D1   38.0
# 1861                              D2   21.0
# 3845                              D1   21.0
# 2871                              D1  124.0
# 2250                              D2   13.0
